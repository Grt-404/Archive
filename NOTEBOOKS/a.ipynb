# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests


response = requests.get(
    "https://catfact.ninja/fact"
)
df = pd.DataFrame([response.json()['fact']])
df
# Out:
#                                                    0
# 0  The strongest climber among the big cats, a le...
