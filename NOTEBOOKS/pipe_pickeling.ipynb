# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))
# here we are loading the pipe.pkl file which contains the pipeline that we have created and trained on the training data, and then we are using that pipeline to make predictions on the test data, and then we are calculating the accuracy of the model on the test data.
# here we are using the predict method of the pipeline to make predictions on the test data,
# and then we are using the accuracy_score function from sklearn.metrics to calculate the accuracy of the model on the test data.

# %%
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S']).reshape(1, -1)
pipe.predict(test_input)
# Out:
# c:\Users\gurpr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\gurpr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
