# %% [markdown]
# <a href="https://colab.research.google.com/github/Grt-404/Archive/blob/main/tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "Hello! how are you?"
def getord(s):
  ans = []
  for i in s:
    ans.append(ord(i))
  return ans
print(getord(a))
# Out:
# [72, 101, 108, 108, 111, 33, 32, 104, 111, 119, 32, 97, 114, 101, 32, 121, 111, 117, 63]

# %%
# why can't we just use it??
# because the unicode standard is stillalive and and keeps on changing so it is indeed not a stable representation

# %%
list("Hello! how are you?".encode("utf-8"))
# Out:
# [72,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  104,
#  111,
#  119,
#  32,
#  97,
#  114,
#  101,
#  32,
#  121,
#  111,
#  117,
#  63]

# %%
list("आ".encode("utf-8"))
# Out:
# [224, 164, 134]

# %%
lst = [12, 12, 12, 15, 15, 6, 4, 12, 12]

# %%
# # WRITING BPE IN CPP
# #include <iostream>
# #include <vector>
# #include <map>
# #include <set>
# #include <algorithm>

# using namespace std;

# int main() {
#     vector<int> v = {12, 12, 12, 15, 15, 6, 4, 12, 12};

#     set<int> vocab(list.begin(), list.end());
#     int max_val = *max_element(list.begin(), list.end());
#     int counter = 0;
#     bool found = true;

#     while (found) {
#         map<pair<int, int>, int> counts;

#         // 1. Count adjacent pairs
#         for (size_t i = 0; i < list.size() - 1; ++i) {
#             counts[{list[i], list[i + 1]}]++;
#         }

#         if (counts.empty()) break;

#         // 2. Find the most frequent pair
#         auto most_frequent = max_element(counts.begin(), counts.end(),
#             [](const auto& p1, const auto& p2) {
#                 return p1.second < p2.second;
#             });

#         // If the top pair doesn't repeat, stop merging
#         if (most_frequent->second < 2) {
#             found = false;
#             break;
#         }

#         pair<int, int> target_pair = most_frequent->first;
#         int new_token = max_val + 1 + counter++;
#         vocab.insert(new_token);

#         // 3. Replace target pair with the new token
#         vector<int> b;
#         size_t a = 0;
#         while (a < list.size()) {
#             if (a < list.size() - 1 && list[a] == target_pair.first && list[a + 1] == target_pair.second) {
#                 b.push_back(new_token);
#                 a += 2; // Skip both merged elements
#             } else {
#                 b.push_back(list[a]);
#                 a += 1;
#             }
#         }
#         list = b; // Update list for next pass
#     }

#     cout << "Final List: ";
#     for (int x : list) cout << x << " ";
#     cout << "\nNew Vocab Size: " << vocab.size() << endl;

#     return 0;
# }
# Out:
#   File "/tmp/ipykernel_777/1530711509.py", line 2
#     int counter = 0;
#         ^
# SyntaxError: invalid syntax

# %%
# text from https://www.reedbeta.com/blog/programmers-intro-to-unicode/
text = "Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception."
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print('---')
print(text)
print("length:", len(text))
print('---')
print(tokens)
print("length:", len(tokens))
# Out:
# ---
# Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.
# length: 533
# ---
# [239, 188, 181, 239, 189, 142, 239, 189, 137, 239, 189, 131, 239, 189, 143, 239, 189, 132, 239, 189, 133, 33, 32, 240, 159, 133, 164, 240, 159, 133, 157, 240, 159, 133, 152, 240, 159, 133, 146, 240, 159, 133, 158, 240, 159, 133, 147, 240, 159, 133, 148, 226, 128, 189, 32, 240, 159, 135, 186, 226, 128, 140, 240, 159, 135, 179, 226, 128, 140, 240, 159, 135, 174, 226, 128, 140, 240, 159, 135, 168, 226, 128, 140, 240, 159, 135, 180, 226, 128, 140, 240, 159, 135, 169, 226, 128, 140, 240, 159, 135, 170, 33, 32, 240, 159, 152, 132, 32, 84, 104, 101, 32, 118, 101, 114, 121, 32, 110, 97, 109, 101, 32, 115, 116, 114, 105, 107, 101, 115, 32, 102, 101, 97, 114, 32, 97, 110, 100, 32, 97, 119, 101, 32, 105, 110, 116, 111, 32, 116, 104, 101, 32, 104, 101, 97, 114, 116, 115, 32, 111, 102, 32, 112, 114, 111, 103, 114, 97, 109, 109, 101, 114, 115, 32, 119, 111, 114, 108, 100, 119, 105, 100, 101, 46, 32, 87, 101, 32, 97, 108, 108, 32, 107, 110, 111, 119, 32, 119, 101, 32, 111, 117, 103, 104, 116, 32, 116, 111, 32, 226, 128, 156, 115, 117, 112, 112, 111, 114, 116, 32, 85, 110, 105, 99, 111, 100, 101, 226, 128, 157, 32, 105, 110, 32, 111, 117, 114, 32, 115, 111, 102, 116, 119, 97, 114, 101, 32, 40, 119, 104, 97, 116, 101, 118, 101, 114, 32, 116, 104, 97, 116, 32, 109, 101, 97, 110, 115, 226, 128, 148, 108, 105, 107, 101, 32, 117, 115, 105, 110, 103, 32, 119, 99, 104, 97, 114, 95, 116, 32, 102, 111, 114, 32, 97, 108, 108, 32, 116, 104, 101, 32, 115, 116, 114, 105, 110, 103, 115, 44, 32, 114, 105, 103, 104, 116, 63, 41, 46, 32, 66, 117, 116, 32, 85, 110, 105, 99, 111, 100, 101, 32, 99, 97, 110, 32, 98, 101, 32, 97, 98, 115, 116, 114, 117, 115, 101, 44, 32, 97, 110, 100, 32, 100, 105, 118, 105, 110, 103, 32, 105, 110, 116, 111, 32, 116, 104, 101, 32, 116, 104, 111, 117, 115, 97, 110, 100, 45, 112, 97, 103, 101, 32, 85, 110, 105, 99, 111, 100, 101, 32, 83, 116, 97, 110, 100, 97, 114, 100, 32, 112, 108, 117, 115, 32, 105, 116, 115, 32, 100, 111, 122, 101, 110, 115, 32, 111, 102, 32, 115, 117, 112, 112, 108, 101, 109, 101, 110, 116, 97, 114, 121, 32, 97, 110, 110, 101, 120, 101, 115, 44, 32, 114, 101, 112, 111, 114, 116, 115, 44, 32, 97, 110, 100, 32, 110, 111, 116, 101, 115, 32, 99, 97, 110, 32, 98, 101, 32, 109, 111, 114, 101, 32, 116, 104, 97, 110, 32, 97, 32, 108, 105, 116, 116, 108, 101, 32, 105, 110, 116, 105, 109, 105, 100, 97, 116, 105, 110, 103, 46, 32, 73, 32, 100, 111, 110, 226, 128, 153, 116, 32, 98, 108, 97, 109, 101, 32, 112, 114, 111, 103, 114, 97, 109, 109, 101, 114, 115, 32, 102, 111, 114, 32, 115, 116, 105, 108, 108, 32, 102, 105, 110, 100, 105, 110, 103, 32, 116, 104, 101, 32, 119, 104, 111, 108, 101, 32, 116, 104, 105, 110, 103, 32, 109, 121, 115, 116, 101, 114, 105, 111, 117, 115, 44, 32, 101, 118, 101, 110, 32, 51, 48, 32, 121, 101, 97, 114, 115, 32, 97, 102, 116, 101, 114, 32, 85, 110, 105, 99, 111, 100, 101, 226, 128, 153, 115, 32, 105, 110, 99, 101, 112, 116, 105, 111, 110, 46]
# length: 616

# %%
from collections import defaultdict

lst = tokens

vocab = set(lst)
counter = 0
max_val = 255 # in utf-8 this is the max value
found = True

while found:
    m = defaultdict(int)
    i = 0

    while i < len(lst) - 1:
        pair = (lst[i], lst[i + 1])
        m[pair] += 1
        i += 1

    v = sorted(m.items(), key=lambda item: item[1], reverse=True)

    if not v or v[0][1] < 2:
        found = False
    else:
        target_pair = v[0][0]
        new_token = max_val + 1 + counter
        vocab.add(new_token)
        counter += 1

        b = []
        a = 0
        while a < len(lst):
            if a < len(lst) - 1 and (lst[a], lst[a + 1]) == target_pair:
                b.append(new_token)
                a += 2
            else:
                b.append(lst[a])
                a += 1

        lst = b
print("Final List:", lst)
print("Vocabulary:", vocab)
print(len(lst))
# Out:
# Final List: [239, 188, 181, 266, 142, 266, 137, 266, 131, 266, 143, 266, 132, 266, 133, 296, 263, 164, 263, 157, 263, 152, 263, 146, 263, 158, 263, 147, 263, 148, 258, 189, 32, 264, 186, 268, 179, 268, 174, 268, 168, 268, 180, 268, 169, 268, 170, 296, 257, 152, 132, 32, 84, 104, 256, 297, 298, 110, 299, 286, 300, 301, 102, 287, 32, 288, 97, 302, 304, 104, 287, 305, 306, 314, 119, 270, 108, 100, 119, 315, 101, 291, 87, 316, 317, 107, 318, 119, 32, 302, 279, 319, 271, 116, 111, 32, 258, 156, 322, 270, 323, 324, 157, 32, 259, 32, 279, 114, 32, 115, 290, 116, 119, 265, 256, 40, 325, 326, 101, 297, 275, 97, 271, 109, 101, 261, 115, 258, 148, 108, 300, 256, 327, 293, 119, 99, 104, 265, 95, 271, 329, 97, 292, 278, 286, 272, 330, 105, 319, 116, 63, 41, 291, 66, 117, 323, 256, 332, 316, 98, 286, 327, 101, 276, 288, 100, 105, 118, 293, 304, 262, 279, 115, 274, 45, 112, 97, 103, 256, 284, 256, 83, 116, 274, 265, 100, 32, 112, 108, 117, 260, 105, 305, 333, 122, 295, 260, 306, 322, 108, 101, 109, 295, 116, 265, 298, 261, 110, 101, 120, 101, 330, 334, 270, 116, 285, 288, 318, 116, 301, 332, 256, 109, 270, 335, 294, 97, 32, 108, 105, 116, 116, 108, 256, 289, 105, 109, 315, 326, 272, 291, 73, 32, 333, 110, 258, 153, 271, 98, 108, 299, 314, 329, 273, 105, 317, 102, 259, 100, 272, 278, 325, 111, 108, 335, 293, 109, 121, 273, 269, 105, 279, 285, 101, 118, 295, 32, 51, 48, 32, 121, 287, 260, 97, 102, 116, 269, 32, 284, 324, 153, 260, 259, 99, 334, 116, 105, 111, 110, 46]
# Vocabulary: {32, 33, 40, 41, 44, 45, 46, 48, 51, 63, 66, 73, 83, 84, 85, 87, 95, 97, 98, 99, 100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 114, 115, 116, 117, 118, 119, 120, 121, 122, 128, 131, 132, 133, 135, 137, 140, 142, 143, 146, 147, 148, 152, 153, 156, 157, 158, 159, 164, 168, 169, 170, 174, 179, 180, 181, 186, 188, 189, 226, 239, 240, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335}
# 300

# %%
# however the above code is correct we still don't use it coz it will explode the size of our vocabukary which will in turn end up , exploding the number of trainable params in the final feed forward neural network
# and so instead of running it tioll there are no repeating pairs we actually tune a hyperparameter and run it till we get a sweet spot of the vocabukary size and the list size
# just for example in my code I will be taking the vocabulary size to be 276

# %%
from collections import defaultdict

lst = tokens

vocab = set(lst)
counter = 0
max_val = 255 # in utf-8 this is the max value


while max(vocab) <277:
    m = defaultdict(int)
    i = 0

    while i < len(lst) - 1:
        pair = (lst[i], lst[i + 1])
        m[pair] += 1
        i += 1

    v = sorted(m.items(), key=lambda item: item[1], reverse=True)

    if not v or v[0][1] < 2:
        break;
    else:
        target_pair = v[0][0]
        new_token = max_val + 1 + counter
        vocab.add(new_token)
        counter += 1

        b = []
        a = 0
        while a < len(lst):
            if a < len(lst) - 1 and (lst[a], lst[a + 1]) == target_pair:
                b.append(new_token)
                a += 2
            else:
                b.append(lst[a])
                a += 1

        lst = b
print("Final List:", lst)
print("Vocabulary:", vocab)
print(len(lst))
# Out:
# Final List: [239, 188, 181, 266, 142, 266, 137, 266, 131, 266, 143, 266, 132, 266, 133, 33, 32, 263, 164, 263, 157, 263, 152, 263, 146, 263, 158, 263, 147, 263, 148, 258, 189, 32, 264, 186, 268, 179, 268, 174, 268, 168, 268, 180, 268, 169, 268, 170, 33, 32, 257, 152, 132, 32, 84, 104, 256, 118, 269, 121, 32, 110, 277, 256, 273, 114, 105, 107, 101, 260, 102, 101, 265, 32, 274, 32, 97, 119, 256, 259, 116, 111, 275, 256, 104, 101, 265, 116, 260, 111, 102, 32, 112, 114, 111, 103, 114, 277, 109, 269, 260, 119, 270, 108, 100, 119, 105, 100, 101, 46, 32, 87, 256, 97, 108, 108, 32, 107, 110, 111, 119, 32, 119, 256, 111, 117, 103, 104, 271, 116, 111, 32, 258, 156, 115, 117, 112, 112, 270, 271, 85, 110, 105, 99, 111, 100, 101, 258, 157, 32, 259, 32, 111, 117, 114, 32, 115, 111, 102, 116, 119, 265, 256, 40, 119, 104, 97, 116, 101, 118, 269, 275, 97, 271, 109, 101, 261, 115, 258, 148, 108, 105, 107, 256, 117, 115, 272, 32, 119, 99, 104, 265, 95, 271, 102, 270, 32, 97, 108, 108, 275, 256, 273, 114, 272, 115, 276, 114, 105, 103, 104, 116, 63, 41, 46, 32, 66, 117, 271, 85, 110, 105, 99, 111, 100, 256, 99, 261, 32, 98, 256, 97, 98, 273, 114, 117, 115, 101, 276, 274, 32, 100, 105, 118, 272, 32, 259, 116, 111, 275, 256, 262, 111, 117, 115, 274, 45, 112, 97, 103, 256, 85, 110, 105, 99, 111, 100, 256, 83, 116, 274, 265, 100, 32, 112, 108, 117, 260, 105, 116, 260, 100, 111, 122, 101, 110, 260, 111, 102, 32, 115, 117, 112, 112, 108, 101, 109, 101, 110, 116, 265, 121, 32, 261, 110, 101, 120, 101, 115, 276, 114, 101, 112, 270, 116, 115, 276, 274, 32, 110, 111, 116, 101, 260, 99, 261, 32, 98, 256, 109, 270, 256, 262, 261, 32, 97, 32, 108, 105, 116, 116, 108, 256, 259, 116, 105, 109, 105, 100, 97, 116, 272, 46, 32, 73, 32, 100, 111, 110, 258, 153, 271, 98, 108, 277, 256, 112, 114, 111, 103, 114, 277, 109, 269, 260, 102, 270, 32, 273, 105, 108, 108, 32, 102, 259, 100, 272, 275, 256, 119, 104, 111, 108, 256, 262, 272, 32, 109, 121, 273, 269, 105, 111, 117, 115, 276, 101, 118, 101, 110, 32, 51, 48, 32, 121, 101, 265, 260, 97, 102, 116, 269, 32, 85, 110, 105, 99, 111, 100, 101, 258, 153, 260, 259, 99, 101, 112, 116, 105, 111, 110, 46]
# Vocabulary: {32, 33, 40, 41, 44, 45, 46, 48, 51, 63, 66, 73, 83, 84, 85, 87, 95, 97, 98, 99, 100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 114, 115, 116, 117, 118, 119, 120, 121, 122, 128, 131, 132, 133, 135, 137, 140, 142, 143, 146, 147, 148, 152, 153, 156, 157, 158, 159, 164, 168, 169, 170, 174, 179, 180, 181, 186, 188, 189, 226, 239, 240, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277}
# 442

# %% [markdown]
# DECODING

# %%
# how to decode the tokens ??
# in the necoder block aboe we will now create a merges dictionary to keep track of what was encoded to what
from collections import defaultdict
counter = 0
lst = tokens.copy()
vocab = set(lst)
max_val = 255  # Base UTF-8 byte range (0-255)

# Dictionary to store token mappings: new_token_id -> (pair_left, pair_right)
merges = {}

while max(vocab) < 277:
    m = defaultdict(int)
    i = 0
    while i < len(lst) - 1:
        pair = (lst[i], lst[i + 1])
        m[pair] += 1
        i += 1

    v = sorted(m.items(), key=lambda item: item[1], reverse=True)

    if not v or v[0][1] < 2:
        break

    target_pair = v[0][0]
    new_token = max_val + 1 + counter
    counter += 1
    vocab.add(new_token)

    # SAVE THE MERGE PAIR HERE
    merges[new_token] = target_pair

    b = []
    a = 0
    while a < len(lst):
        if a < len(lst) - 1 and (lst[a], lst[a + 1]) == target_pair:
            b.append(new_token)
            a += 2
        else:
            b.append(lst[a])
            a += 1
    lst = b

# %%
def decode_token(token_id):
    # Base case: if it's a raw UTF-8 byte (0-255), return it directly
    if token_id <= 255:
        return [token_id]

    # Recursive case: split the token back into its parent pair and expand both
    left, right = merges[token_id]
    return decode_token(left) + decode_token(right)

def decode(token_list):
    # 1. Expand all tokens into raw byte values (0-255)
    raw_bytes = []
    for token in token_list:
        raw_bytes.extend(decode_token(token))

    # 2. Convert byte integers back to a UTF-8 string
    return bytes(raw_bytes).decode("utf-8")

# %% [markdown]
# BUT THERE IS A PROBLEM WITH IT

# %%
decode([128])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_1281/1685474992.py in <cell line: 0>()
# ----> 1 decode([128])
#
# /tmp/ipykernel_1281/2626902434.py in decode(token_list)
#      15
#      16     # 2. Convert byte integers back to a UTF-8 string
# ---> 17     return bytes(raw_bytes).decode("utf-8")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %% [markdown]
# 128 is 1 followed by all zeroes, that does not follow rules of utf 8

# %%
# how to correct it??
def decode_token(token_id):
    # Base case: if it's a raw UTF-8 byte (0-255), return it directly
    if token_id <= 255:
        return [token_id]

    # Recursive case: split the token back into its parent pair and expand both
    left, right = merges[token_id]
    return decode_token(left) + decode_token(right)

def decode(token_list):
    # 1. Expand all tokens into raw byte values (0-255)
    raw_bytes = []
    for token in token_list:
        raw_bytes.extend(decode_token(token))

    # 2. Convert byte integers back to a UTF-8 string
    return bytes(raw_bytes).decode("utf-8", errors = "replace") #THIS WAS CHANGED IN OPEN AI'S CODE

# %%
decode([128 ])
# Out:
# '�'

# %% [markdown]
# ENCODING

# %%
# suppose there is a new text you wanna encode, you cannot just re run the bpe because the llm has now been trained on the corpus, it has learnt that 256 -> "the", so re running bpe would just break down everything apart

# %%
# we have the merges dictionary, and we need to follow the order of those merges
def encode(text):
    tokens = list(text.encode("utf-8"))

    # 2. Apply merges in chronological training order
    for new_token, pair in merges.items():
        i = 0
        new_tokens = []
        while i < len(tokens):
            # Check if adjacent pair matches current merge rule
            if i < len(tokens) - 1 and (tokens[i], tokens[i + 1]) == pair:
                new_tokens.append(new_token)
                i += 2  # Skip both merged elements
            else:
                new_tokens.append(tokens[i])
                i += 1
        tokens = new_tokens

    return tokens

# %%
r = encode("hekko")
print(r)
# Out:
# [104, 101, 107, 107, 111]

# %%
decode(r)
# Out:
# 'hello world'
