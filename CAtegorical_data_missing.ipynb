# %%
# MOST_FREQUENT_VALUE imputation

# if the data is mcar

# this is the most common imputation technique for categorical variables where we fill the missing values with the most frequent value of the column but this technique can be used for numerical variables as well but it is not recommended because it can distort the distribution of the data and it can also lead to overfitting because the model can learn that this is a missing value and it can learn from it

# Apply it only when less than 10% of the data is missing in the column because if more than 10% of the data is missing then it can distort the distribution of the data and it can also lead to overfitting because the model can learn that this is a missing value and it can learn from it
# Advantages:
# 1. It is simple and easy to implement.
#Disadvantages:
# 1. It can distort the distribution of the data.

# %%
#Missing CAtegory Imputation
# if the data is not mcar
# Wherever the data is missing in the categorical variable we can fill it with a new category called 'Missing' or 'Unknown' so that the model can learn that this is a missing value and it can learn from it
# so we will create a new category called 'Missing' and fill the missing values with this category
